# %%
X = {
    "Sajjad":{"math": 100, "English": 95},
    "David":{"math": 95, "English": 100}
}
print(X.items())
# Out:
# dict_items([('Sajjad', {'math': 100, 'English': 95}), ('David', {'math': 95, 'English': 100})])

# %%
X = {
    "Sajjad":{"math": 100, "English": 95},
    "David":{"math": 95, "English": 100}
}
print(X.values())
# Out:
# dict_values([{'math': 100, 'English': 95}, {'math': 95, 'English': 100}])

# %%
X = {
    "Sajjad":{"math": 100, "English": 95},
    "David":{"math": 95, "English": 100}
}
print(X.keys())
# Out:
# dict_keys(['Sajjad', 'David'])

# %%
X = {
    "Sajjad":{"math": 100, "English": 95},
    "David":{"math": 95, "English": 100}
}
# print(X.get("Sajjad"))
print(X.get("Sajj"))
# Out:
# None

# %%
X = {
    "Sajjad":{"math": 100, "English": 95},
    "David":{"math": 95, "English": 100}
}
print(X["Sajjad"] ["English"])
print(X["David"] ["English"])
print(X)
# Out:
# 95
# 100
# {'Sajjad': {'math': 100, 'English': 95}, 'David': {'math': 95, 'English': 100}}

# %%
X = {
    "Sajjad":{"math": 100, "English": 95},
    "David":{"math": 95, "English": 100}
}
X["Solomon"] = {"math": 80, "English": 90}
print(X)
# Out:
# {'Sajjad': {'math': 100, 'English': 95}, 'David': {'math': 95, 'English': 100}, 'Solomon': {'math': 80, 'English': 90}}

# %%
X = {
    "Sajjad":{"math": 100, "English": 95},
    "David":{"math": 95, "English": 100}
}
X.pop("Sajjad")
print(X)
# Out:
# {'David': {'math': 95, 'English': 100}}

# %%
X = {
    "name":"David",
      "age": 10  
     }
print(X ["name"])
# Out:
# David
